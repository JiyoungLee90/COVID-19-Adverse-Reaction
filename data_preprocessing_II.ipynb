# %% [markdown]
# # Data Preprocessing
#
# - Combine two datasets(symptom & comorbidity)
#
# - Delete patients records that contains missing values
#
# - Transform AGE_YRS to AGE_GRP

# %%
import pandas as pd
import numpy as np
import re

# %%
covid_adv_sym = pd.read_csv('dataset/covid_adv_symptom.csv')
covid_adv_co = pd.read_csv('dataset/covid_adv_comorbidity.csv')

# %% [markdown]
# ### Combine datasets

# %%
covid_adv = pd.merge(covid_adv_sym, covid_adv_co, how = 'left', on = ['VAERS_ID', 'AGE_YRS',
                                                                      'SEX', 'DIED', 'VAX_MANU'])

# %%
covid_adv
# Out:
#         VAERS_ID  AGE_YRS SEX DIED         VAX_MANU Headache Pyrexia Fatigue  \
# 0        1410490     54.0   F   No  PFIZER\BIONTECH       No      No      No
# 1        1413866     67.0   M   No          MODERNA       No      No      No
# 2         896636     47.0   F   No          MODERNA       No      No      No
# 3         902418     56.0   F   No  PFIZER\BIONTECH       No      No      No
# 4         902440     35.0   F   No  PFIZER\BIONTECH       No      No     Yes
# ...          ...      ...  ..  ...              ...      ...     ...     ...
# 404844   1427468     17.0   F   No  PFIZER\BIONTECH       No      No      No
# 404845   1427471     18.0   M   No          MODERNA       No      No      No
# 404846   1427472     54.0   F   No          MODERNA       No      No      No
# 404847   1427475     87.0   F  Yes          MODERNA       No      No      No
# 404848   1427476     56.0   F   No          MODERNA       No      No      No
#
#        Chills Swelling  ... Depression_c Hypothyroidsm_c High_Cholesterol_c  \
# 0          No       No  ...           No              No                 No
# 1          No      Yes  ...           No              No                 No
# 2          No       No  ...           No              No                 No
# 3          No       No  ...           No              No                 No
# 4          No       No  ...           No              No                 No
# ...       ...      ...  ...          ...             ...                ...
# 404844     No       No  ...           No              No                 No
# 404845     No       No  ...           No              No                 No
# 404846     No       No  ...           No              No                 No
# 404847     No       No  ...           No              No                 No
# 404848     No       No  ...           No              No                 No
#
#        Heart_Disease_c GERD_c Cancer_c Obesity_c Migraine_c Kidney_Disease_c  \
# 0                   No     No       No        No         No               No
# 1                   No     No       No        No         No               No
# 2                   No     No       No        No         No               No
# 3                   No     No       No        No         No               No
# 4                   No     No       No        No         No               No
# ...                ...    ...      ...       ...        ...              ...
# 404844              No     No       No        No         No               No
# 404845              No     No       No        No         No               No
# 404846              No     No       No        No         No               No
# 404847              No     No       No        No         No               No
# 404848              No     No       No        No         No               No
#
#        COVID19_Positive
# 0                    No
# 1                    No
# 2                    No
# 3                    No
# 4                    No
# ...                 ...
# 404844               No
# 404845               No
# 404846               No
# 404847               No
# 404848               No
#
# [404849 rows x 80 columns]

# %% [markdown]
# ### Missing Value
#
# - Age -> Delete from 404849 to 378693
#
# - Gender -> Delete (Unknown) to 376566
#
# - Vaccine manufacturer -> Delete(UNKNOWN MANUFACTURER) to 375804

# %%
# Delete rows with missing age
covid_adv = covid_adv.dropna(subset=['AGE_YRS'])

# %%
# Delete rows with SEX == 'Unknown'
covid_adv = covid_adv[covid_adv.SEX != 'U']

# %%
# Delete rows with VAX_MANU == 'Unknown'
covid_adv = covid_adv[covid_adv.VAX_MANU != 'UNKNOWN MANUFACTURER']

# %% [markdown]
# ### Transform Variables
#
# - Age YRS to Age GRP

# %%
# Age
age_group = []
for age in covid_adv['AGE_YRS']:
    if age in range(0, 18):
        age_group.append('0-17')
    elif age in range(18, 35):
        age_group.append('18-34')
    elif age in range(35, 50):
        age_group.append('35-49')
    elif age in range(50, 65):
        age_group.append('50-64')
    elif age in range(65, 80):
        age_group.append('65-79')
    else:
        age_group.append('>= 80')
        
# create new variable        
covid_adv['AGE_GRP'] = age_group

# %%
covid_adv
# Out:
#         VAERS_ID  AGE_YRS SEX DIED         VAX_MANU Headache Pyrexia Fatigue  \
# 0        1410490     54.0   F   No  PFIZER\BIONTECH       No      No      No
# 1        1413866     67.0   M   No          MODERNA       No      No      No
# 2         896636     47.0   F   No          MODERNA       No      No      No
# 3         902418     56.0   F   No  PFIZER\BIONTECH       No      No      No
# 4         902440     35.0   F   No  PFIZER\BIONTECH       No      No     Yes
# ...          ...      ...  ..  ...              ...      ...     ...     ...
# 404844   1427468     17.0   F   No  PFIZER\BIONTECH       No      No      No
# 404845   1427471     18.0   M   No          MODERNA       No      No      No
# 404846   1427472     54.0   F   No          MODERNA       No      No      No
# 404847   1427475     87.0   F  Yes          MODERNA       No      No      No
# 404848   1427476     56.0   F   No          MODERNA       No      No      No
#
#        Chills Swelling  ... Hypothyroidsm_c High_Cholesterol_c  \
# 0          No       No  ...              No                 No
# 1          No      Yes  ...              No                 No
# 2          No       No  ...              No                 No
# 3          No       No  ...              No                 No
# 4          No       No  ...              No                 No
# ...       ...      ...  ...             ...                ...
# 404844     No       No  ...              No                 No
# 404845     No       No  ...              No                 No
# 404846     No       No  ...              No                 No
# 404847     No       No  ...              No                 No
# 404848     No       No  ...              No                 No
#
#        Heart_Disease_c GERD_c Cancer_c Obesity_c Migraine_c Kidney_Disease_c  \
# 0                   No     No       No        No         No               No
# 1                   No     No       No        No         No               No
# 2                   No     No       No        No         No               No
# 3                   No     No       No        No         No               No
# 4                   No     No       No        No         No               No
# ...                ...    ...      ...       ...        ...              ...
# 404844              No     No       No        No         No               No
# 404845              No     No       No        No         No               No
# 404846              No     No       No        No         No               No
# 404847              No     No       No        No         No               No
# 404848              No     No       No        No         No               No
#
#        COVID19_Positive AGE_GRP
# 0                    No   50-59
# 1                    No   60-69
# 2                    No   40-49
# 3                    No   50-59
# 4                    No   30-39
# ...                 ...     ...
# 404844               No   10-19
# 404845               No   10-19
# 404846               No   50-59
# 404847               No   80-89
# 404848               No   50-59
#
# [375804 rows x 81 columns]

# %%
covid_adv.to_csv('covid_adv.csv', index = False)
